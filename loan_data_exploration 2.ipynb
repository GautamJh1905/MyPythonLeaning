# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the loan dataset
df = pd.read_csv(r'Loan dataset_classification.csv')
print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %%
# Display first 5 rows
print("First 5 rows (head):")
df.head()
# Out:
# First 5 rows (head):
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
# Display last 5 rows
print("Last 5 rows (tail):")
df.tail()
# Out:
# Last 5 rows (tail):
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 976  LP002971   Male     Yes         3+  Not Graduate           Yes
# 977  LP002975   Male     Yes          0      Graduate            No
# 978  LP002980   Male      No          0      Graduate            No
# 979  LP002986   Male     Yes          0      Graduate            No
# 980  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 976             4009             1777.0       113.0             360.0
# 977             4158              709.0       115.0             360.0
# 978             3250             1993.0       126.0             360.0
# 979             5000             2393.0       158.0             360.0
# 980             9200                0.0        98.0             180.0
#
#      Credit_History Property_Area Loan_Status
# 976             1.0         Urban         NaN
# ...

# %%
# Shape of the dataset
print("Shape of dataset (rows, columns):")
print(df.shape)
print(f"\nNumber of rows: {df.shape[0]:,}")
print(f"Number of columns: {df.shape[1]}")
# Out:
# Shape of dataset (rows, columns):
# (981, 13)
#
# Number of rows: 981
# Number of columns: 13

# %%
# Column names
print("Column names:")
print(df.columns.tolist())
# Out:
# Column names:
# ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status']

# %%
# Dataset info
print("Dataset Info:")
df.info()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 981 entries, 0 to 980
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            981 non-null    object
#  1   Gender             957 non-null    object
#  2   Married            978 non-null    object
#  3   Dependents         956 non-null    object
#  4   Education          981 non-null    object
#  5   Self_Employed      926 non-null    object
#  6   ApplicantIncome    981 non-null    int64
#  7   CoapplicantIncome  981 non-null    float64
#  8   LoanAmount         954 non-null    float64
#  9   Loan_Amount_Term   961 non-null    float64
#  10  Credit_History     902 non-null    float64
#  11  Property_Area      981 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 99.8+ KB

# %%
# Data types of each column
print("Data types of each column:")
print(df.dtypes)
# Out:
# Data types of each column:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
# Check for null values
print("Null values in each column:")
print(df.isnull().sum())

print("\nTotal null values in dataset:")
print(df.isnull().sum().sum())

print("\nPercentage of null values in each column:")
print((df.isnull().sum() / len(df)) * 100)
# Out:
# Null values in each column:
# Loan_ID                0
# Gender                24
# Married                3
# Dependents            25
# Education              0
# Self_Employed         55
# ApplicantIncome        0
# CoapplicantIncome      0
# LoanAmount            27
# Loan_Amount_Term      20
# Credit_History        79
# Property_Area          0
# Loan_Status          367
# dtype: int64
#
# Total null values in dataset:
# 600
#
# Percentage of null values in each column:
# Loan_ID               0.000000
# Gender                2.446483
# Married               0.305810
# Dependents            2.548420
# Education             0.000000
# Self_Employed         5.606524
# ApplicantIncome       0.000000
# CoapplicantIncome     0.000000
# LoanAmount            2.752294
# Loan_Amount_Term      2.038736
# Credit_History        8.053007
# Property_Area         0.000000
# Loan_Status          37.410805
# dtype: float64

# %%
# Basic statistics for numerical columns
print("Statistical summary (describe):")
df.describe()
# Out:
# Statistical summary (describe):
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       981.000000         981.000000  954.000000        961.000000
# mean       5179.795107        1601.916330  142.511530        342.201873
# std        5695.104533        2718.772806   77.421743         65.100602
# min           0.000000           0.000000    9.000000          6.000000
# 25%        2875.000000           0.000000  100.000000        360.000000
# 50%        3800.000000        1110.000000  126.000000        360.000000
# 75%        5516.000000        2365.000000  162.000000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History
# count      902.000000
# mean         0.835920
# std          0.370553
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
# Additional statistics for all columns including non-numeric
print("Statistical summary for all columns:")
df.describe(include='all')
# Out:
# Statistical summary for all columns:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        981    957     978        956       981           926
# unique       981      2       2          4         2             2
# top     LP001002   Male     Yes          0  Graduate            No
# freq           1    775     631        545       763           807
# mean         NaN    NaN     NaN        NaN       NaN           NaN
# std          NaN    NaN     NaN        NaN       NaN           NaN
# min          NaN    NaN     NaN        NaN       NaN           NaN
# 25%          NaN    NaN     NaN        NaN       NaN           NaN
# 50%          NaN    NaN     NaN        NaN       NaN           NaN
# 75%          NaN    NaN     NaN        NaN       NaN           NaN
# max          NaN    NaN     NaN        NaN       NaN           NaN
#
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
# Visualize null values - Bar chart
print("Null Values Visualization:")

null_counts = df.isnull().sum()
# Only show columns with null values
null_counts = null_counts[null_counts > 0]

if len(null_counts) > 0:
    plt.figure(figsize=(10, 6))
    plt.bar(null_counts.index, null_counts.values, color='coral')
    plt.xlabel('Column Names', fontsize=12)
    plt.ylabel('Number of Null Values', fontsize=12)
    plt.title('Null Values Count by Column', fontsize=14, fontweight='bold')
    plt.xticks(rotation=45, ha='right')
    plt.grid(axis='y', alpha=0.3)
    plt.tight_layout()
    plt.show()
else:
    print("No null values found in the dataset!")
# Out:
# Null Values Visualization:

# %%
# Visualize null percentage - Horizontal bar chart
null_percentage = (df.isnull().sum() / len(df)) * 100
null_percentage = null_percentage[null_percentage > 0]

if len(null_percentage) > 0:
    plt.figure(figsize=(10, 6))
    plt.barh(null_percentage.index, null_percentage.values, color='indianred')
    plt.xlabel('Percentage of Null Values (%)', fontsize=12)
    plt.ylabel('Column Names', fontsize=12)
    plt.title('Null Values Percentage by Column', fontsize=14, fontweight='bold')
    plt.grid(axis='x', alpha=0.3)
    plt.tight_layout()
    plt.show()
else:
    print("No null values to display!")

# %%
# Heatmap-style visualization for null values
plt.figure(figsize=(12, 8))
plt.imshow(df.isnull(), cmap='viridis', aspect='auto', interpolation='nearest')
plt.colorbar(label='Missing Data (1=Missing, 0=Present)')
plt.xlabel('Column Index', fontsize=12)
plt.ylabel('Row Index', fontsize=12)
plt.title('Null Values Heatmap (Yellow = Missing)', fontsize=14, fontweight='bold')
plt.xticks(range(len(df.columns)), df.columns, rotation=90)
plt.tight_layout()
plt.show()

# %%
# Fill null values in 'Married' column with mode (most frequent value)

# Check if column exists
if 'Married' in df.columns:
    # Count nulls before
    null_before = df['Married'].isnull().sum()
    print(f"Null values in 'Married' before filling: {null_before}")
    
    # Find mode (most frequent value)
    married_mode = df['Married'].mode()[0]
    print(f"Mode of 'Married' column: {married_mode}")
    
    # Fill null values with mode
    df['Married'].fillna(married_mode, inplace=True)
    
    # Count nulls after
    null_after = df['Married'].isnull().sum()
    print(f"Null values in 'Married' after filling: {null_after}")
    
    # Show value counts
    print("\nValue counts in 'Married' column:")
    print(df['Married'].value_counts())
else:
    print("Column 'Married' not found in dataset!")
    print(f"Available columns: {df.columns.tolist()}")
# Out:
# Null values in 'Married' before filling: 3
# Mode of 'Married' column: Yes
# Null values in 'Married' after filling: 0
#
# Value counts in 'Married' column:
# Married
# Yes    634
# No     347
# Name: count, dtype: int64
# C:\Users\JHAGAUT\AppData\Local\Temp\ipykernel_28316\2804405093.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Married'].fillna(married_mode, inplace=True)

# %%
# Analyze null columns and suggest best filling method
print("="*80)
print("RECOMMENDED FILLING STRATEGIES FOR NULL COLUMNS")
print("="*80)

null_cols = df.columns[df.isnull().any()].tolist()

if len(null_cols) > 0:
    for col in null_cols:
        null_count = df[col].isnull().sum()
        null_pct = (null_count / len(df)) * 100
        dtype = df[col].dtype
        
        print(f"\n📊 Column: {col}")
        print(f"   Type: {dtype}")
        print(f"   Nulls: {null_count} ({null_pct:.2f}%)")
        
        # Suggest filling method based on type and characteristics
        if pd.api.types.is_numeric_dtype(df[col]):
            # Check for outliers using IQR
            Q1 = df[col].quantile(0.25)
            Q3 = df[col].quantile(0.75)
            IQR = Q3 - Q1
            outliers = df[(df[col] < (Q1 - 1.5 * IQR)) | (df[col] > (Q3 + 1.5 * IQR))][col].count()
            
            if outliers > len(df) * 0.05:  # More than 5% outliers
                print(f"   ✅ RECOMMENDED: MEDIAN (has {outliers} outliers)")
            else:
                print(f"   ✅ RECOMMENDED: MEAN (no significant outliers)")
            print(f"   📈 Mean: {df[col].mean():.2f}, Median: {df[col].median():.2f}")
        else:
            # Categorical column
            mode_val = df[col].mode()[0] if len(df[col].mode()) > 0 else "N/A"
            unique_count = df[col].nunique()
            print(f"   ✅ RECOMMENDED: MODE (most frequent value)")
            print(f"   📈 Mode: {mode_val}, Unique values: {unique_count}")
            print(f"   Alternative: 'Unknown' or 'Not Available'")
else:
    print("No null columns found!")
# Out:
# ...
# RECOMMENDED FILLING STRATEGIES FOR NULL COLUMNS
# ...
#
# 📊 Column: Gender
#    Type: object
#    Nulls: 24 (2.45%)
#    ✅ RECOMMENDED: MODE (most frequent value)
#    📈 Mode: Male, Unique values: 2
#    Alternative: 'Unknown' or 'Not Available'
#
# 📊 Column: Dependents
#    Type: object
#    Nulls: 25 (2.55%)
#    ✅ RECOMMENDED: MODE (most frequent value)
#    📈 Mode: 0, Unique values: 4
#    Alternative: 'Unknown' or 'Not Available'
#
# 📊 Column: Self_Employed
#    Type: object
#    Nulls: 55 (5.61%)
#    ✅ RECOMMENDED: MODE (most frequent value)
#    📈 Mode: No, Unique values: 2
#    Alternative: 'Unknown' or 'Not Available'
#
# 📊 Column: LoanAmount
#    Type: float64
#    Nulls: 27 (2.75%)
#    ✅ RECOMMENDED: MEDIAN (has 65 outliers)
#    📈 Mean: 142.51, Median: 126.00
#
# 📊 Column: Loan_Amount_Term
#    Type: float64
#    Nulls: 20 (2.04%)
#    ✅ RECOMMENDED: MEDIAN (has 138 outliers)
#    📈 Mean: 342.20, Median: 360.00
#
# 📊 Column: Credit_History
#    Type: float64
# ...

# %%
# Apply recommended filling strategies
print("Filling null values with recommended strategies...\n")

# Categorical columns - fill with MODE
df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])
print(f"✓ Gender filled with mode: {df['Gender'].mode()[0]}")

df['Dependents'] = df['Dependents'].fillna(df['Dependents'].mode()[0])
print(f"✓ Dependents filled with mode: {df['Dependents'].mode()[0]}")

df['Self_Employed'] = df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])
print(f"✓ Self_Employed filled with mode: {df['Self_Employed'].mode()[0]}")

# Numerical columns - fill with MEDIAN (due to outliers)
df['LoanAmount'] = df['LoanAmount'].fillna(df['LoanAmount'].median())
print(f"✓ LoanAmount filled with median: {df['LoanAmount'].median()}")

df['Loan_Amount_Term'] = df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].median())
print(f"✓ Loan_Amount_Term filled with median: {df['Loan_Amount_Term'].median()}")

df['Credit_History'] = df['Credit_History'].fillna(df['Credit_History'].median())
print(f"✓ Credit_History filled with median: {df['Credit_History'].median()}")

# Loan_Status - fill with mode
df['Loan_Status'] = df['Loan_Status'].fillna(df['Loan_Status'].mode()[0])
print(f"✓ Loan_Status filled with mode: {df['Loan_Status'].mode()[0]}")

# Verify no nulls remain
print("\n" + "="*60)
print("VERIFICATION: Remaining null values")
print("="*60)
remaining_nulls = df.isnull().sum()
if remaining_nulls.sum() == 0:
    print("✅ SUCCESS: All null values have been filled!")
else:
    print(remaining_nulls[remaining_nulls > 0])
# Out:
# Filling null values with recommended strategies...
#
# ✓ Gender filled with mode: Male
# ✓ Dependents filled with mode: 0
# ✓ Self_Employed filled with mode: No
# ✓ LoanAmount filled with median: 126.0
# ✓ Loan_Amount_Term filled with median: 360.0
# ✓ Credit_History filled with median: 1.0
# ✓ Loan_Status filled with mode: Y
#
# ...
# VERIFICATION: Remaining null values
# ...
# ✅ SUCCESS: All null values have been filled!

# %%
# Check if target column (Loan_Status) is balanced or imbalanced
print("="*70)
print("TARGET COLUMN BALANCE CHECK: Loan_Status")
print("="*70)

# Count and percentage distribution
value_counts = df['Loan_Status'].value_counts()
value_percentage = df['Loan_Status'].value_counts(normalize=True) * 100

print("\nValue Counts:")
print(value_counts)
print("\nPercentage Distribution:")
print(value_percentage)

# Calculate balance ratio
total = value_counts.sum()
majority_class = value_counts.max()
minority_class = value_counts.min()
balance_ratio = minority_class / majority_class

print(f"\nTotal samples: {total}")
print(f"Majority class: {majority_class} ({(majority_class/total)*100:.2f}%)")
print(f"Minority class: {minority_class} ({(minority_class/total)*100:.2f}%)")
print(f"Balance ratio: {balance_ratio:.2f}")

# Determine if balanced or imbalanced
print("\n" + "="*70)
if balance_ratio >= 0.8:
    print("✅ BALANCED: Dataset is well balanced (ratio >= 0.8)")
elif balance_ratio >= 0.6:
    print("⚠️ SLIGHTLY IMBALANCED: Dataset is slightly imbalanced (0.6 <= ratio < 0.8)")
else:
    print("❌ IMBALANCED: Dataset is imbalanced (ratio < 0.6)")
    print("   Consider using techniques like SMOTE, undersampling, or class weights")
print("="*70)

# Visualize the distribution
plt.figure(figsize=(10, 5))

# Bar plot
plt.subplot(1, 2, 1)
value_counts.plot(kind='bar', color=['skyblue', 'lightcoral'])
plt.title('Loan_Status Distribution (Count)', fontsize=12, fontweight='bold')
plt.xlabel('Loan Status', fontsize=10)
plt.ylabel('Count', fontsize=10)
plt.xticks(rotation=0)
plt.grid(axis='y', alpha=0.3)

# Pie chart
plt.subplot(1, 2, 2)
plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%', 
        colors=['skyblue', 'lightcoral'], startangle=90)
plt.title('Loan_Status Distribution (Percentage)', fontsize=12, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# ...
# TARGET COLUMN BALANCE CHECK: Loan_Status
# ...
#
# Value Counts:
# Loan_Status
# Y    789
# N    192
# Name: count, dtype: int64
#
# Percentage Distribution:
# Loan_Status
# Y    80.428135
# N    19.571865
# Name: proportion, dtype: float64
#
# Total samples: 981
# Majority class: 789 (80.43%)
# Minority class: 192 (19.57%)
# Balance ratio: 0.24
#
# ...
# ❌ IMBALANCED: Dataset is imbalanced (ratio < 0.6)
#    Consider using techniques like SMOTE, undersampling, or class weights
# ...

# %%
# Apply SMOTE to balance the dataset
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import LabelEncoder

print("="*70)
print("APPLYING SMOTE TO BALANCE THE DATASET")
print("="*70)

# Prepare data: Encode categorical variables for SMOTE
# SMOTE requires numerical data, so we need to encode categorical columns

# Create a copy of the dataframe for encoding
df_encoded = df.copy()

# Store label encoders for later reference
label_encoders = {}

# Encode all categorical columns
categorical_columns = df_encoded.select_dtypes(include=['object']).columns.tolist()

print("\nEncoding categorical columns...")
for col in categorical_columns:
    if col != 'Loan_Status':  # Don't encode target yet
        le = LabelEncoder()
        df_encoded[col] = le.fit_transform(df_encoded[col])
        label_encoders[col] = le
        print(f"  ✓ {col} encoded")

# Separate features and target
X = df_encoded.drop('Loan_Status', axis=1)
y = df_encoded['Loan_Status']

# Encode target variable
le_target = LabelEncoder()
y_encoded = le_target.fit_transform(y)

print(f"\nOriginal dataset shape: {X.shape}")
print(f"Original class distribution:")
print(f"  Y (Approved): {(y == 'Y').sum()}")
print(f"  N (Not Approved): {(y == 'N').sum()}")

# Apply SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y_encoded)

print(f"\nAfter SMOTE:")
print(f"Resampled dataset shape: {X_resampled.shape}")
print(f"Resampled class distribution:")
unique, counts = np.unique(y_resampled, return_counts=True)
for val, count in zip(unique, counts):
    label = le_target.inverse_transform([val])[0]
    print(f"  {label}: {count}")

# Create balanced dataframe
df_balanced = pd.DataFrame(X_resampled, columns=X.columns)
df_balanced['Loan_Status'] = le_target.inverse_transform(y_resampled)

# Decode categorical columns back to original values
print("\nDecoding categorical columns back...")
for col in label_encoders.keys():
    # Round to nearest integer and convert to int for decoding
    df_balanced[col] = df_balanced[col].round().astype(int)
    # Ensure values are within valid range
    df_balanced[col] = df_balanced[col].clip(0, len(label_encoders[col].classes_) - 1)
    df_balanced[col] = label_encoders[col].inverse_transform(df_balanced[col])
    print(f"  ✓ {col} decoded")

print("\n" + "="*70)
print("✅ SMOTE APPLIED SUCCESSFULLY!")
print(f"Final balanced dataset shape: {df_balanced.shape}")
print("="*70)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[130], line 2
#       1 # Apply SMOTE to balance the dataset
# ----> 2 from imblearn.over_sampling import SMOTE
#       3 from sklearn.preprocessing import LabelEncoder
#       5 print("="*70)
#
# ModuleNotFoundError: No module named 'imblearn'

# %%
# Visualize the before and after SMOTE comparison
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Before SMOTE
original_counts = df['Loan_Status'].value_counts()
axes[0].bar(original_counts.index, original_counts.values, color=['skyblue', 'lightcoral'])
axes[0].set_title('Before SMOTE - Imbalanced Dataset', fontsize=13, fontweight='bold')
axes[0].set_xlabel('Loan Status', fontsize=11)
axes[0].set_ylabel('Count', fontsize=11)
axes[0].set_ylim(0, 850)
axes[0].grid(axis='y', alpha=0.3)
for i, v in enumerate(original_counts.values):
    axes[0].text(i, v + 20, str(v), ha='center', fontweight='bold')

# After SMOTE
balanced_counts = df_balanced['Loan_Status'].value_counts()
axes[1].bar(balanced_counts.index, balanced_counts.values, color=['skyblue', 'lightcoral'])
axes[1].set_title('After SMOTE - Balanced Dataset', fontsize=13, fontweight='bold')
axes[1].set_xlabel('Loan Status', fontsize=11)
axes[1].set_ylabel('Count', fontsize=11)
axes[1].set_ylim(0, 850)
axes[1].grid(axis='y', alpha=0.3)
for i, v in enumerate(balanced_counts.values):
    axes[1].text(i, v + 20, str(v), ha='center', fontweight='bold')

plt.tight_layout()
plt.show()

print("\n" + "="*70)
print("SUMMARY:")
print("="*70)
print(f"Original dataset: {df.shape[0]} samples (Y: 789, N: 192)")
print(f"Balanced dataset: {df_balanced.shape[0]} samples (Y: 789, N: 789)")
print(f"Synthetic samples created: {df_balanced.shape[0] - df.shape[0]}")
print("="*70)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 16
#      13     axes[0].text(i, v + 20, str(v), ha='center', fontweight='bold')
#      15 # After SMOTE
# ---> 16 balanced_counts = df_balanced['Loan_Status'].value_counts()
#      17 axes[1].bar(balanced_counts.index, balanced_counts.values, color=['skyblue', 'lightcoral'])
#      18 axes[1].set_title('After SMOTE - Balanced Dataset', fontsize=13, fontweight='bold')
#
# NameError: name 'df_balanced' is not defined

# %%
# Display the final balanced dataframe
print("="*70)
print("FINAL BALANCED DATAFRAME (df_balanced)")
print("="*70)

print(f"\nShape: {df_balanced.shape}")
print(f"Columns: {df_balanced.columns.tolist()}\n")

print("First 10 rows:")
display(df_balanced.head(10))

print("\nLast 10 rows:")
display(df_balanced.tail(10))

print("\nDataframe Info:")
df_balanced.info()

print("\nTarget Variable Distribution:")
print(df_balanced['Loan_Status'].value_counts())

print("\nStatistical Summary:")
display(df_balanced.describe())
# Out:
# ...
# FINAL BALANCED DATAFRAME (df_balanced)
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 6
#       3 print("FINAL BALANCED DATAFRAME (df_balanced)")
#       4 print("="*70)
# ----> 6 print(f"\nShape: {df_balanced.shape}")
#       7 print(f"Columns: {df_balanced.columns.tolist()}\n")
#       9 print("First 10 rows:")
#
# NameError: name 'df_balanced' is not defined

# %%
# Save the balanced dataset to a new CSV file
output_path = r'C:\Work\SourceCode\Python\ML Learning\Data\Loan_dataset_balanced.csv'

df_balanced.to_csv(output_path, index=False)

print("="*70)
print("FILE SAVED SUCCESSFULLY!")
print("="*70)
print(f"\nOutput file: {output_path}")
print(f"Rows saved: {df_balanced.shape[0]}")
print(f"Columns saved: {df_balanced.shape[1]}")
print(f"File size: {df_balanced.memory_usage(deep=True).sum() / 1024:.2f} KB")
print("\n✅ The balanced dataset has been saved and is ready for model training!")
print("="*70)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 4
#       1 # Save the balanced dataset to a new CSV file
#       2 output_path = r'C:\Work\SourceCode\Python\ML Learning\Data\Loan_dataset_balanced.csv'
# ----> 4 df_balanced.to_csv(output_path, index=False)
#       6 print("="*70)
#       7 print("FILE SAVED SUCCESSFULLY!")
#
# NameError: name 'df_balanced' is not defined

# %%
from sklearn.linear_model import LogisticRegression
import seaborn as sb
pd.crosstab(df['Married'],df['Loan_Status'],normalize="index")*100
# Out:
# Loan_Status          N          Y
# Married
# No           22.766571  77.233429
# Yes          17.823344  82.176656

# %%
# Check the mode of Dependents column
print("="*60)
print("MODE OF DEPENDENTS COLUMN")
print("="*60)

dependents_mode = df['Dependents'].mode()[0]
print(f"\nMode (most frequent value): {dependents_mode}")

print("\nValue counts:")
print(df['Dependents'].value_counts())

print("\nValue counts with percentages:")
print(df['Dependents'].value_counts(normalize=True) * 100)
# Out:
# ...
# MODE OF DEPENDENTS COLUMN
# ...
#
# Mode (most frequent value): 0
#
# Value counts:
# Dependents
# 0    661
# 1    160
# 2    160
# Name: count, dtype: int64
#
# Value counts with percentages:
# Dependents
# 0    67.380224
# 1    16.309888
# 2    16.309888
# Name: proportion, dtype: float64

# %%
# Investigate why '3' is not showing - check unique values and data
print("="*70)
print("INVESTIGATING DEPENDENTS COLUMN")
print("="*70)

print("\nUnique values in Dependents column:")
print(df['Dependents'].unique())

print("\nData type:")
print(df['Dependents'].dtype)

print("\nComplete value counts (including all categories):")
print(df['Dependents'].value_counts(dropna=False))

print("\nChecking for '3' or '3+' values:")
print(f"Count of '3': {(df['Dependents'] == '3').sum()}")
print(f"Count of '3+': {(df['Dependents'] == '3+').sum()}")

print("\n" + "="*70)
print("EXPLANATION:")
print("="*70)
print("""
The '3+' category was likely filled with mode value '0' during the 
null value filling process (cell 17), which happened BEFORE the 
replacement code was executed.

When you filled null values with mode='0', all 25 null values in 
Dependents were replaced with '0', eliminating the original '3+' 
values that may have been null.

To see the original '3+' values, you need to:
1. Reload the dataset fresh
2. Replace '3+' with '3' FIRST
3. Then fill null values
""")
# Out:
# ...
# INVESTIGATING DEPENDENTS COLUMN
# ...
#
# Unique values in Dependents column:
# ['0' '1' '2']
#
# Data type:
# object
#
# Complete value counts (including all categories):
# Dependents
# 0    661
# 1    160
# 2    160
# Name: count, dtype: int64
#
# Checking for '3' or '3+' values:
# Count of '3': 0
# Count of '3+': 0
#
# ...
# EXPLANATION:
# ...
#
# The '3+' category was likely filled with mode value '0' during the
# null value filling process (cell 17), which happened BEFORE the
# replacement code was executed.
#
# When you filled null values with mode='0', all 25 null values in
# Dependents were replaced with '0', eliminating the original '3+'
# values that may have been null.
#
# To see the original '3+' values, you need to:
# 1. Reload the dataset fresh
# 2. Replace '3+' with '3' FIRST
# 3. Then fill null values

# %%
# Let's reload the dataset and check if '3+' exists in the original data
df_original = pd.read_csv(r'Loan dataset_classification.csv')

print("="*70)
print("CHECKING ORIGINAL DATASET FOR '3+' VALUES")
print("="*70)

print("\nUnique values in original Dependents column:")
print(df_original['Dependents'].unique())

print("\nValue counts in original data:")
print(df_original['Dependents'].value_counts(dropna=False))

print(f"\nCount of '3+' in original data: {(df_original['Dependents'] == '3+').sum()}")
print(f"Count of NaN in original data: {df_original['Dependents'].isnull().sum()}")
# Out:
# ...
# CHECKING ORIGINAL DATASET FOR '3+' VALUES
# ...
#
# Unique values in original Dependents column:
# ['0' '1' '2' '3+' nan]
#
# Value counts in original data:
# Dependents
# 0      545
# 1      160
# 2      160
# 3+      91
# NaN     25
# Name: count, dtype: int64
#
# Count of '3+' in original data: 91
# Count of NaN in original data: 25

# %%
print("="*70)
print("SOLUTION: THE CORRECT ORDER")
print("="*70)

print("""
WHAT HAPPENED:
- Original data had 91 records with '3+' dependents
- You filled null values FIRST (cell 17), which replaced nulls with '0'
- Then you tried to replace '3+' with '3', but by that time the data
  had already been processed

CORRECT ORDER FOR DATA PREPROCESSING:
1. Load data
2. Replace '3+' with '3' (clean categorical values)
3. Fill null values with mode
4. Continue with other preprocessing

CURRENT STATE:
- Your current df has: 661 zeros, 160 ones, 160 twos
- The '3+' values (91 records) were NOT replaced because your 
  replacement code ran AFTER null filling had already altered the data
- To fix this, you would need to reload the data and apply 
  transformations in the correct order
""")
# Out:
# ...
# SOLUTION: THE CORRECT ORDER
# ...
#
# WHAT HAPPENED:
# - Original data had 91 records with '3+' dependents
# - You filled null values FIRST (cell 17), which replaced nulls with '0'
# - Then you tried to replace '3+' with '3', but by that time the data
#   had already been processed
#
# CORRECT ORDER FOR DATA PREPROCESSING:
# 1. Load data
# 2. Replace '3+' with '3' (clean categorical values)
# 3. Fill null values with mode
# 4. Continue with other preprocessing
#
# CURRENT STATE:
# - Your current df has: 661 zeros, 160 ones, 160 twos
# - The '3+' values (91 records) were NOT replaced because your
#   replacement code ran AFTER null filling had already altered the data
# - To fix this, you would need to reload the data and apply
#   transformations in the correct order

# %%
# Replace '3+' with '3' in Dependents column
print("="*60)
print("CONVERTING '3+' TO '3' IN DEPENDENTS COLUMN")
print("="*60)

print("\nBefore replacement:")
print(df['Dependents'].value_counts())

# Replace '3+' with '3'
df['Dependents'] = df['Dependents'].replace('3+', '3')

print("\nAfter replacement:")
print(df['Dependents'].value_counts())

print("\n✅ Successfully replaced '3+' with '3'")
# Out:
# ...
# CONVERTING '3+' TO '3' IN DEPENDENTS COLUMN
# ...
#
# Before replacement:
# Dependents
# 0    661
# 1    160
# 2    160
# Name: count, dtype: int64
#
# After replacement:
# Dependents
# 0    661
# 1    160
# 2    160
# Name: count, dtype: int64
#
# ✅ Successfully replaced '3+' with '3'

# %%
# RESET: Reload the dataset to start fresh
print("="*70)
print("RESETTING DATASET - LOADING FRESH DATA")
print("="*70)

df = pd.read_csv(r'Loan dataset_classification.csv')

print("\n✅ Dataset reloaded successfully!")
print(f"Shape: {df.shape}")
print(f"\nUnique values in Dependents column:")
print(df['Dependents'].unique())
print(f"\nValue counts:")
print(df['Dependents'].value_counts(dropna=False))
print(f"\nNull values in dataset:")
print(df.isnull().sum().sum())

print("\n" + "="*70)
print("Dataset is now back to its original state!")
print("="*70)
# Out:
# ...
# RESETTING DATASET - LOADING FRESH DATA
# ...
#
# ✅ Dataset reloaded successfully!
# Shape: (981, 13)
#
# Unique values in Dependents column:
# ['0' '1' '2' '3+' nan]
#
# Value counts:
# Dependents
# 0      545
# 1      160
# 2      160
# 3+      91
# NaN     25
# Name: count, dtype: int64
#
# Null values in dataset:
# 600
#
# ...
# Dataset is now back to its original state!
# ...

# %%
# Clean Dependents column: Replace '3+' with '3' and NaN with '0'
print("="*70)
print("CLEANING DEPENDENTS COLUMN")
print("="*70)

print("\nBefore cleaning:")
print(df['Dependents'].value_counts(dropna=False))

# Step 1: Replace '3+' with '3'
df['Dependents'] = df['Dependents'].replace('3+', '3')
print("\nAfter replacing '3+' with '3':")
print(df['Dependents'].value_counts(dropna=False))

# Step 2: Fill NaN values with '0'
df['Dependents'] = df['Dependents'].fillna('0')
print("\nAfter filling NaN with '0':")
print(df['Dependents'].value_counts(dropna=False))

print("\n" + "="*70)
print("✅ CLEANING COMPLETE!")
print("="*70)
print(f"Total records: {len(df)}")
print(f"Null values remaining in Dependents: {df['Dependents'].isnull().sum()}")
# Out:
# ...
# CLEANING DEPENDENTS COLUMN
# ...
#
# Before cleaning:
# Dependents
# 0    570
# 1    160
# 2    160
# 3     91
# Name: count, dtype: int64
#
# After replacing '3+' with '3':
# Dependents
# 0    570
# 1    160
# 2    160
# 3     91
# Name: count, dtype: int64
#
# After filling NaN with '0':
# Dependents
# 0    570
# 1    160
# 2    160
# 3     91
# Name: count, dtype: int64
#
# ...
# ✅ CLEANING COMPLETE!
# ...
# Total records: 981
# Null values remaining in Dependents: 0
