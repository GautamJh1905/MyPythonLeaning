# %%
import pandas as pd
df = pd.read_csv("Emp_Data.csv")
#print(df.sort_values (by = "salary", ascending =False))
#print(df.groupby("city").size())
#print(df[df.salary.isnull()])
#print(df["salary"].mean())

# Replace null values in salary column with the mean
df["salary"] = df["salary"].fillna(df["salary"].mean())

# Save the updated DataFrame back to CSV
df.to_csv("Emp_Data.csv", index=False)
print("Null values in salary column replaced with mean and saved to CSV!")
# Out:
# Null values in salary column replaced with mean and saved to CSV!
